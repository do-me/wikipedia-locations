# %%
import requests
from bs4 import BeautifulSoup
import os

# The base URL for the files
base_url = "http://files.bendodson.com.s3.amazonaws.com/wikilocation-dumps/"

# The HTML content containing the file links
html_content = """
<h1>WikiLocation MySQL Dumps</h1>
<ul>
<li><a href="http://files.bendodson.com.s3.amazonaws.com/wikilocation-dumps/ar.sql.gz">ar.sql.gz</a></li>
<li><a href="http://files.bendodson.com.s3.amazonaws.com/wikilocation-dumps/bg.sql.gz">bg.sql.gz</a></li>
<li><a href="http://files.bendodson.com.s3.amazonaws.com/wikilocation-dumps/ca.sql.gz">ca.sql.gz</a></li>
<li><a href="http://files.bendodson.com.s3.amazonaws.com/wikilocation-dumps/cs.sql.gz">cs.sql.gz</a></li>
<li><a href="http://files.bendodson.com.s3.amazonaws.com/wikilocation-dumps/da.sql.gz">da.sql.gz</a></li>
<li><a href="http://files.bendodson.com.s3.amazonaws.com/wikilocation-dumps/de.sql.gz">de.sql.gz</a></li>
<li><a href="http://files.bendodson.com.s3.amazonaws.com/wikilocation-dumps/en.sql.gz">en.sql.gz</a></li>
<li><a href="http://files.bendodson.com.s3.amazonaws.com/wikilocation-dumps/eo.sql.gz">eo.sql.gz</a></li>
<li><a href="http://files.bendodson.com.s3.amazonaws.com/wikilocation-dumps/es.sql.gz">es.sql.gz</a></li>
<li><a href="http://files.bendodson.com.s3.amazonaws.com/wikilocation-dumps/fa.sql.gz">fa.sql.gz</a></li>
<li><a href="http://files.bendodson.com.s3.amazonaws.com/wikilocation-dumps/fi.sql.gz">fi.sql.gz</a></li>
<li><a href="http://files.bendodson.com.s3.amazonaws.com/wikilocation-dumps/fr.sql.gz">fr.sql.gz</a></li>
<li><a href="http://files.bendodson.com.s3.amazonaws.com/wikilocation-dumps/gl.sql.gz">gl.sql.gz</a></li>
<li><a href="http://files.bendodson.com.s3.amazonaws.com/wikilocation-dumps/he.sql.gz">he.sql.gz</a></li>
<li><a href="http://files.bendodson.com.s3.amazonaws.com/wikilocation-dumps/hu.sql.gz">hu.sql.gz</a></li>
<li><a href="http://files.bendodson.com.s3.amazonaws.com/wikilocation-dumps/id.sql.gz">id.sql.gz</a></li>
<li><a href="http://files.bendodson.com.s3.amazonaws.com/wikilocation-dumps/it.sql.gz">it.sql.gz</a></li>
<li><a href="http://files.bendodson.com.s3.amazonaws.com/wikilocation-dumps/ja.sql.gz">ja.sql.gz</a></li>
<li><a href="http://files.bendodson.com.s3.amazonaws.com/wikilocation-dumps/ko.sql.gz">ko.sql.gz</a></li>
<li><a href="http://files.bendodson.com.s3.amazonaws.com/wikilocation-dumps/lt.sql.gz">lt.sql.gz</a></li>
<li><a href="http://files.bendodson.com.s3.amazonaws.com/wikilocation-dumps/ms.sql.gz">ms.sql.gz</a></li>
<li><a href="http://files.bendodson.com.s3.amazonaws.com/wikilocation-dumps/nl.sql.gz">nl.sql.gz</a></li>
<li><a href="http://files.bendodson.com.s3.amazonaws.com/wikilocation-dumps/nn.sql.gz">nn.sql.gz</a></li>
<li><a href="http://files.bendodson.com.s3.amazonaws.com/wikilocation-dumps/no.sql.gz">no.sql.gz</a></li>
<li><a href="http://files.bendodson.com.s3.amazonaws.com/wikilocation-dumps/pl.sql.gz">pl.sql.gz</a></li>
<li><a href="http://files.bendodson.com.s3.amazonaws.com/wikilocation-dumps/pt.sql.gz">pt.sql.gz</a></li>
<li><a href="http://files.bendodson.com.s3.amazonaws.com/wikilocation-dumps/ro.sql.gz">ro.sql.gz</a></li>
<li><a href="http://files.bendodson.com.s3.amazonaws.com/wikilocation-dumps/ru.sql.gz">ru.sql.gz</a></li>
<li><a href="http://files.bendodson.com.s3.amazonaws.com/wikilocation-dumps/simple.sql.gz">simple.sql.gz</a></li>
<li><a href="http://files.bendodson.com.s3.amazonaws.com/wikilocation-dumps/sk.sql.gz">sk.sql.gz</a></li>
<li><a href="http://files.bendodson.com.s3.amazonaws.com/wikilocation-dumps/sl.sql.gz">sl.sql.gz</a></li>
<li><a href="http://files.bendodson.com.s3.amazonaws.com/wikilocation-dumps/sr.sql.gz">sr.sql.gz</a></li>
<li><a href="http://files.bendodson.com.s3.amazonaws.com/wikilocation-dumps/sv.sql.gz">sv.sql.gz</a></li>
<li><a href="http://files.bendodson.com.s3.amazonaws.com/wikilocation-dumps/tr.sql.gz">tr.sql.gz</a></li>
<li><a href="http://files.bendodson.com.s3.amazonaws.com/wikilocation-dumps/uk.sql.gz">uk.sql.gz</a></li>
<li><a href="http://files.bendodson.com.s3.amazonaws.com/wikilocation-dumps/vi.sql.gz">vi.sql.gz</a></li>
<li><a href="http://files.bendodson.com.s3.amazonaws.com/wikilocation-dumps/vo.sql.gz">vo.sql.gz</a></li>
<li><a href="http://files.bendodson.com.s3.amazonaws.com/wikilocation-dumps/war.sql.gz">war.sql.gz</a></li>
<li><a href="http://files.bendodson.com.s3.amazonaws.com/wikilocation-dumps/zh.sql.gz">zh.sql.gz</a></li>
</ul>
"""

# Parse the HTML content
soup = BeautifulSoup(html_content, 'html.parser')

# Find all the <a> tags within the <ul>
links = soup.find_all('a')

# Ensure the download directory exists
download_dir = "data"
if not os.path.exists(download_dir):
    os.makedirs(download_dir)

# Download each file
for link in links:
    file_url = link.get('href')
    file_name = file_url.split('/')[-1]
    response = requests.get(file_url, stream=True)
    
    # Check if the request was successful
    if response.status_code == 200:
        with open(os.path.join(download_dir, file_name), 'wb') as file:
            for chunk in response.iter_content(chunk_size=1024):
                if chunk:
                    file.write(chunk)
        print(f"Downloaded {file_name}")
    else:
        print(f"Failed to download {file_name}")
# Out:
# Downloaded ar.sql.gz
# Downloaded bg.sql.gz
# Downloaded ca.sql.gz
# Downloaded cs.sql.gz
# Downloaded da.sql.gz
# Downloaded de.sql.gz
# Downloaded en.sql.gz
# Downloaded eo.sql.gz
# Downloaded es.sql.gz
# Downloaded fa.sql.gz
# Downloaded fi.sql.gz
# Downloaded fr.sql.gz
# Downloaded gl.sql.gz
# Downloaded he.sql.gz
# Downloaded hu.sql.gz
# Downloaded id.sql.gz
# Downloaded it.sql.gz
# Downloaded ja.sql.gz
# Downloaded ko.sql.gz
# Downloaded lt.sql.gz
# Downloaded ms.sql.gz
# Downloaded nl.sql.gz
# Downloaded nn.sql.gz
# Downloaded no.sql.gz
# Downloaded pl.sql.gz
# Downloaded pt.sql.gz
# Downloaded ro.sql.gz
# Downloaded ru.sql.gz
# Downloaded simple.sql.gz
# Downloaded sk.sql.gz
# Downloaded sl.sql.gz
# Downloaded sr.sql.gz
# Downloaded sv.sql.gz
# Downloaded tr.sql.gz
# Downloaded uk.sql.gz
# Downloaded vi.sql.gz
# Downloaded vo.sql.gz
# Downloaded war.sql.gz
# Downloaded zh.sql.gz
